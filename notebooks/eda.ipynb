# %%
! pymol -c ../data/pdb/train/1A6K.pdb -d "ray; png 1A6K.png, dpi=300; quit"
! pymol -c ../data/pdb/train/146L.pdb -d "ray; png 146L.png, dpi=300; quit"
! pymol -c ../data/pdb/test/4IRX.pdb -d "ray; png 4IRX.png, dpi=300; quit"

# %%
from IPython.display import Image, display

display(Image(filename="1A6K.png"))
display(Image(filename="146L.png"))
display(Image(filename="4IRX.png"))
